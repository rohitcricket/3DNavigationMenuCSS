# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitcricket/3DNavigationMenuCSS/blob/master/SpatialLMMTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clone the repository
# !git clone https://github.com/manycore-research/SpatialLM.git
# %cd SpatialLM

# create a conda environment with cuda 12.4
# !conda create -n spatiallm python=3.11
# !conda activate spatiallm
# !conda install -y nvidia/label/cuda-12.4.0::cuda-toolkit conda-forge::sparsehash

# Install dependencies with poetry
# !pip install poetry && poetry config virtualenvs.create false --local
# !poetry install
# !poe install-torchsparse # Building wheel for torchsparse will take a while
# Out:
# Cloning into 'SpatialLM'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 68 (delta 3), reused 3 (delta 3), pack-reused 59 (from 1)
# Receiving objects: 100% (68/68), 6.37 MiB | 11.39 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/SpatialLM
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.2/331.2 kB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 36.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 6.0 MB/s eta 0:00:00
# ...
